# %%
import sys
sys.path.insert(1, '../')
from heterogenous_game_theory import *
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
# %matplotlib inline
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
plt.style.use('fivethirtyeight')
seed = 2
np.random.seed(seed)

tour_type = "hetero_mdr_sd_max"
M = [5, 12.5]
R = [0.4, 1.25]
D = [0.3, 1.25]

agents = get_agents(homogenous = False, M = M, R = R, D = D)
check_parameters(agents)
compare_payoff_function(agents, default_payoff_functions)

tour = Tournament.create_play_tournament(
                 agents = agents, 
                 max_rounds = 10000, 
                 strategy_list = [defect, tit_for_tat, generous_tit_for_tat, cooperate], 
                 payoff_functions = default_payoff_functions, 
                 surveillance_penalty = True,
                 self_reward = selfreward, #default function
                 playing_each_other = True,
                 nr_strategy_changes = 10,
                 mutation_rate = 0.1,
                 init_fitnes_as_m = False,
                 noise = 0.05,
                 )
draw_stack(tour)
C_D_ratios_per_round_var(tour, constant = 1)
outliers = count_outliers(tour, constants = np.arange(0.5, 3.1, 0.1))
data = {'S.D.': list(outliers.keys()), 'Counts': list(outliers.values())}
df = pd.DataFrame.from_dict(data)
print(df)
df.to_csv("data/outliers/" + str(seed) + "_outlier_counts.csv", encoding='utf-8', index = False, float_format='%.1f')
save_tournament_csv(tour, seed = str(seed))
# Out:
# <style>.container { width:90% !important; }</style>
# AGENT PARAMETERS IN POPULATION
# -------------------------------------
#    M 		  D 		  R
# -------------------------------------
# | 9.1 		 0.16 		 0.9 |
# | 4.1 		 0.41 		 0.35 |
# | 0.7 		 0.06 		 0.66 |
# | 7.9 		 0.27 		 0.89 |
# | 8.1 		 0.88 		 0.32 |
# | 7.5 		 0.21 		 0.97 |
# | 8.2 		 0.84 		 0.26 |
# | 4.4 		 0.54 		 0.34 |
# | 6.1 		 0.06 		 0.11 |
# | 6.9 		 0.85 		 0.67 |
# | 6.5 		 0.34 		 0.27 |
# | 9.2 		 0.52 		 0.82 |
# | 8.9 		 0.09 		 0.04 |
# | 4.1 		 0.47 		 0.51 |
# | 5.0 		 0.98 		 0.41 |
# | 7.4 		 0.81 		 0.83 |
# | 9.0 		 0.49 		 0.26 |
# | 7.4 		 0.18 		 0.94 |
# | 2.2 		 0.67 		 0.59 |
# -------------------------------------
# The s.d. of M is: 2.72
# The s.d. of D is: 0.29
# The s.d. of R is: 0.3
# -------------------------------------
# The mean of M is: 5.51
# The mean of D is: 0.49
# The mean of R is: 0.47
# -------------------------------------
# ____________________________________________________________________________________________________
# Agent 0 playing Agent 1: Reward: 4.3, Temptation: 8.0, Sucker: 0, Punishment: 3.7
# Agent 1 playing Agent 0: Reward: 6.9, Temptation: 10.1, Sucker: 0, Punishment: 3.2
# ____________________________________________________________________________________________________
# Agent 0 playing Agent 2: Reward: 0.7, Temptation: 1.4, Sucker: 0, Punishment: 0.6
# Agent 2 playing Agent 0: Reward: 6.6, Temptation: 12.6, Sucker: 0, Punishment: 6.0
# ____________________________________________________________________________________________________
# Agent 0 playing Agent 3: Reward: 8.4, Temptation: 15.5, Sucker: 0, Punishment: 7.1
# Agent 3 playing Agent 0: Reward: 10.6, Temptation: 18.7, Sucker: 0, Punishment: 8.1
# ____________________________________________________________________________________________________
# Agent 0 playing Agent 4: Reward: 8.6, Temptation: 15.9, Sucker: 0, Punishment: 7.3
# Agent 4 playing Agent 0: Reward: 10.9, Temptation: 13.8, Sucker: 0, Punishment: 2.9
# ____________________________________________________________________________________________________
# Agent 1 playing Agent 2: Reward: 0.5, Temptation: 0.8, Sucker: 0, Punishment: 0.2
# Agent 2 playing Agent 1: Reward: 3.0, Temptation: 5.7, Sucker: 0, Punishment: 2.7
# ____________________________________________________________________________________________________
# Agent 1 playing Agent 3: Reward: 6.0, Temptation: 8.8, Sucker: 0, Punishment: 2.8
# Agent 3 playing Agent 1: Reward: 4.8, Temptation: 8.4, Sucker: 0, Punishment: 3.6
# ____________________________________________________________________________________________________
# Agent 1 playing Agent 4: Reward: 6.2, Temptation: 9.0, Sucker: 0, Punishment: 2.8
# Agent 4 playing Agent 1: Reward: 4.9, Temptation: 6.2, Sucker: 0, Punishment: 1.3
# ____________________________________________________________________________________________________
# Agent 2 playing Agent 3: Reward: 5.7, Temptation: 10.9, Sucker: 0, Punishment: 5.2
# Agent 3 playing Agent 2: Reward: 0.8, Temptation: 1.4, Sucker: 0, Punishment: 0.6
# ____________________________________________________________________________________________________
# Agent 2 playing Agent 4: Reward: 5.8, Temptation: 11.2, Sucker: 0, Punishment: 5.3
# Agent 4 playing Agent 2: Reward: 0.8, Temptation: 1.1, Sucker: 0, Punishment: 0.2
# ____________________________________________________________________________________________________
# Agent 3 playing Agent 4: Reward: 9.4, Temptation: 16.6, Sucker: 0, Punishment: 7.2
# Agent 4 playing Agent 3: Reward: 9.5, Temptation: 12.0, Sucker: 0, Punishment: 2.5
#
# All players are playing a prisoners dilemma
# Tournament has started...
# |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-514b7c50dd2d> in <module>()
#      32                  mutation_rate = 0.1,
#      33                  init_fitnes_as_m = False,
# ---> 34                  noise = 0.05,
#      35                  )
#      36 draw_stack(tour)
#
# C:\Users\vocelik\Documents\projects\heterogenous_game_theory\heterogenous_game_theory\tournament.py in create_play_tournament(cls, agents, max_rounds, strategy_list, payoff_functions, surveillance_penalty, self_reward, playing_each_other, nr_strategy_changes, mutation_rate, init_fitnes_as_m, noise)
#     444         tournament.init_fitness(init_fitnes_as_m=init_fitnes_as_m)
#     445
# --> 446         tournament.play(self_reward, playing_each_other, nr_strategy_changes, mutation_rate)
#     447
#     448         return tournament
#
# C:\Users\vocelik\Documents\projects\heterogenous_game_theory\heterogenous_game_theory\tournament.py in play(self, self_reward, playing_each_other, nr_strategy_changes, mutation_rate)
#     356                 for agent_1, agent_2, data in self.graph.edges(data=True): # data: include edge-attributes in the iteration
#     357                     # todo: we are looping though edges twice.. this could be done only once.
# --> 358                     self.play_prisoners_dilema(agent_1, agent_2, data)
#     359
#     360             for _ in range(nr_strategy_changes):
#
# C:\Users\vocelik\Documents\projects\heterogenous_game_theory\heterogenous_game_theory\tournament.py in play_prisoners_dilema(self, agent_1, agent_2, game)
#     281
#     282         # let agents' strategies choose an action
# --> 283         action_1 = agent_1.select_action(game['history_1'], game['history_2'], self.noise)
#     284         action_2 = agent_2.select_action(game['history_2'], game['history_1'], self.noise)
#     285
#
# C:\Users\vocelik\Documents\projects\heterogenous_game_theory\heterogenous_game_theory\agent.py in select_action(self, selfmoves, othermoves, noise_threshold)
#      44
#      45     def select_action(self, selfmoves, othermoves, noise_threshold):
# ---> 46         r = np.random.uniform()
#      47         if r < noise_threshold:
#      48             # there is a chance of {noise_threshold} that this action will
#
# KeyboardInterrupt:
