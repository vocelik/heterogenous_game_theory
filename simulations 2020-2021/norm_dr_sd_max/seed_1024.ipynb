# %%
import sys
sys.path.insert(1, '../')
from heterogenous_game_theory import *
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
# %matplotlib inline
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
plt.style.use('fivethirtyeight')
seed = 1024
np.random.seed(seed)

tour_type = "hetero_dr_sd_max"
M = [5, 1/10000]
R = [0.4, 1.25]
D = [0.3, 1.25]

agents = get_agents(homogenous = False, M = M, R = R, D = D)
check_parameters(agents)
compare_payoff_function(agents, default_payoff_functions)

tour = Tournament.create_play_tournament(
                 agents = agents, 
                 max_rounds = 10000, 
                 strategy_list = [defect, tit_for_tat, generous_tit_for_tat, cooperate], 
                 payoff_functions = default_payoff_functions, 
                 surveillance_penalty = True,
                 self_reward = selfreward, #default function
                 playing_each_other = True,
                 nr_strategy_changes = 10,
                 mutation_rate = 0.1,
                 init_fitnes_as_m = False,
                 noise = 0.05,
                 )
draw_stack(tour)
C_D_ratios_per_round_var(tour, constant = 1)
outliers = count_outliers(tour, constants = np.arange(0.5, 3.1, 0.1))
data = {'S.D.': list(outliers.keys()), 'Counts': list(outliers.values()), 'seed': seed, 'tournament_type': tour_type}
df = pd.DataFrame.from_dict(data)
print(df)
df.to_csv("data/outliers/" + str(seed) + "_outlier_counts.csv", encoding='utf-8', index = False, float_format='%.1f')
save_tournament_csv(tour, seed = str(seed), tour_type = tour_type)
# Out:
# <style>.container { width:90% !important; }</style>
# AGENT PARAMETERS IN POPULATION
# -------------------------------------
#    M 		  D 		  R
# -------------------------------------
# | 5.0 		 0.25 		 0.14 |
# | 5.0 		 0.93 		 0.71 |
# | 5.0 		 0.99 		 0.28 |
# | 5.0 		 0.36 		 0.84 |
# | 5.0 		 0.03 		 0.81 |
# | 5.0 		 0.02 		 0.26 |
# | 5.0 		 0.58 		 0.15 |
# | 5.0 		 0.54 		 0.4 |
# | 5.0 		 0.04 		 0.71 |
# | 5.0 		 0.44 		 0.75 |
# | 5.0 		 0.44 		 0.52 |
# | 5.0 		 0.69 		 0.84 |
# | 5.0 		 0.08 		 0.2 |
# | 5.0 		 0.33 		 0.46 |
# | 5.0 		 0.63 		 0.53 |
# | 5.0 		 0.75 		 0.78 |
# | 5.0 		 0.42 		 0.45 |
# | 5.0 		 0.19 		 0.92 |
# | 5.0 		 0.64 		 0.0 |
# -------------------------------------
# The s.d. of M is: 0.0
# The s.d. of D is: 0.29
# The s.d. of R is: 0.3
# -------------------------------------
# The mean of M is: 5.0
# The mean of D is: 0.53
# The mean of R is: 0.47
# -------------------------------------
# ____________________________________________________________________________________________________
# Agent 0 playing Agent 1: Reward: 2.0, Temptation: 2.7, Sucker: 0, Punishment: 0.7
# Agent 1 playing Agent 0: Reward: 8.2, Temptation: 11.8, Sucker: 0, Punishment: 3.6
# ____________________________________________________________________________________________________
# Agent 0 playing Agent 2: Reward: 2.0, Temptation: 2.7, Sucker: 0, Punishment: 0.7
# Agent 2 playing Agent 0: Reward: 6.4, Temptation: 7.8, Sucker: 0, Punishment: 1.4
# ____________________________________________________________________________________________________
# Agent 0 playing Agent 3: Reward: 2.0, Temptation: 2.7, Sucker: 0, Punishment: 0.7
# Agent 3 playing Agent 0: Reward: 6.0, Temptation: 10.2, Sucker: 0, Punishment: 4.2
# ____________________________________________________________________________________________________
# Agent 0 playing Agent 4: Reward: 2.0, Temptation: 2.7, Sucker: 0, Punishment: 0.7
# Agent 4 playing Agent 0: Reward: 4.2, Temptation: 8.2, Sucker: 0, Punishment: 4.1
# ____________________________________________________________________________________________________
# Agent 1 playing Agent 2: Reward: 8.2, Temptation: 11.8, Sucker: 0, Punishment: 3.6
# Agent 2 playing Agent 1: Reward: 6.4, Temptation: 7.8, Sucker: 0, Punishment: 1.4
# ____________________________________________________________________________________________________
# Agent 1 playing Agent 3: Reward: 8.2, Temptation: 11.8, Sucker: 0, Punishment: 3.6
# Agent 3 playing Agent 1: Reward: 6.0, Temptation: 10.2, Sucker: 0, Punishment: 4.2
# ____________________________________________________________________________________________________
# Agent 1 playing Agent 4: Reward: 8.2, Temptation: 11.8, Sucker: 0, Punishment: 3.6
# Agent 4 playing Agent 1: Reward: 4.2, Temptation: 8.2, Sucker: 0, Punishment: 4.1
# ____________________________________________________________________________________________________
# Agent 2 playing Agent 3: Reward: 6.4, Temptation: 7.8, Sucker: 0, Punishment: 1.4
# Agent 3 playing Agent 2: Reward: 6.0, Temptation: 10.2, Sucker: 0, Punishment: 4.2
# ____________________________________________________________________________________________________
# Agent 2 playing Agent 4: Reward: 6.4, Temptation: 7.8, Sucker: 0, Punishment: 1.4
# Agent 4 playing Agent 2: Reward: 4.2, Temptation: 8.2, Sucker: 0, Punishment: 4.1
# ____________________________________________________________________________________________________
# Agent 3 playing Agent 4: Reward: 6.0, Temptation: 10.2, Sucker: 0, Punishment: 4.2
# Agent 4 playing Agent 3: Reward: 4.2, Temptation: 8.2, Sucker: 0, Punishment: 4.1
#
# All players are playing a prisoners dilemma
# Tournament has started...
# Tournament has ended. The simulation took 38 minutes.
#     S.D.  Counts  seed   tournament_type
# 0    0.5     248  1024  hetero_dr_sd_max
# 1    0.6     234  1024  hetero_dr_sd_max
# 2    0.7     235  1024  hetero_dr_sd_max
# 3    0.8     219  1024  hetero_dr_sd_max
# 4    0.9     205  1024  hetero_dr_sd_max
# 5    1.0     204  1024  hetero_dr_sd_max
# 6    1.1     198  1024  hetero_dr_sd_max
# 7    1.2     165  1024  hetero_dr_sd_max
# 8    1.3     139  1024  hetero_dr_sd_max
# 9    1.4     121  1024  hetero_dr_sd_max
# 10   1.5     115  1024  hetero_dr_sd_max
# 11   1.6      96  1024  hetero_dr_sd_max
# 12   1.7      82  1024  hetero_dr_sd_max
# 13   1.8      69  1024  hetero_dr_sd_max
# 14   1.9      52  1024  hetero_dr_sd_max
# 15   2.0      27  1024  hetero_dr_sd_max
# 16   2.1      22  1024  hetero_dr_sd_max
# 17   2.2      21  1024  hetero_dr_sd_max
# 18   2.3      13  1024  hetero_dr_sd_max
# 19   2.4       8  1024  hetero_dr_sd_max
# 20   2.5       5  1024  hetero_dr_sd_max
# 21   2.6       3  1024  hetero_dr_sd_max
# 22   2.7       1  1024  hetero_dr_sd_max
# 23   2.8       1  1024  hetero_dr_sd_max
# 24   2.9       1  1024  hetero_dr_sd_max
# 25   3.0       0  1024  hetero_dr_sd_max
