# %%
import sys
sys.path.insert(1, '../')
from heterogenous_game_theory import *
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
# %matplotlib inline
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
plt.style.use('fivethirtyeight')
seed = 256
np.random.seed(seed)

tour_type = "hetero_dr_sd_max"
M = [5, 1/10000]
R = [0.4, 1.25]
D = [0.3, 1.25]

agents = get_agents(homogenous = False, M = M, R = R, D = D)
check_parameters(agents)
compare_payoff_function(agents, default_payoff_functions)

tour = Tournament.create_play_tournament(
                 agents = agents, 
                 max_rounds = 10000, 
                 strategy_list = [defect, tit_for_tat, generous_tit_for_tat, cooperate], 
                 payoff_functions = default_payoff_functions, 
                 surveillance_penalty = True,
                 self_reward = selfreward, #default function
                 playing_each_other = True,
                 nr_strategy_changes = 10,
                 mutation_rate = 0.1,
                 init_fitnes_as_m = False,
                 noise = 0.05,
                 )
draw_stack(tour)
C_D_ratios_per_round_var(tour, constant = 1)
outliers = count_outliers(tour, constants = np.arange(0.5, 3.1, 0.1))
data = {'S.D.': list(outliers.keys()), 'Counts': list(outliers.values()), 'seed': seed, 'tournament_type': tour_type}
df = pd.DataFrame.from_dict(data)
print(df)
df.to_csv("data/outliers/" + str(seed) + "_outlier_counts.csv", encoding='utf-8', index = False, float_format='%.1f')
save_tournament_csv(tour, seed = str(seed), tour_type = tour_type)
# Out:
# <style>.container { width:90% !important; }</style>
# AGENT PARAMETERS IN POPULATION
# -------------------------------------
#    M 		  D 		  R
# -------------------------------------
# | 5.0 		 0.05 		 0.22 |
# | 5.0 		 0.24 		 0.55 |
# | 5.0 		 0.48 		 0.01 |
# | 5.0 		 0.74 		 0.55 |
# | 5.0 		 0.5 		 0.84 |
# | 5.0 		 0.91 		 0.19 |
# | 5.0 		 0.38 		 0.37 |
# | 5.0 		 0.85 		 0.42 |
# | 5.0 		 0.12 		 0.57 |
# | 5.0 		 0.14 		 0.2 |
# | 5.0 		 0.16 		 0.47 |
# | 5.0 		 0.41 		 0.92 |
# | 5.0 		 0.38 		 0.0 |
# | 5.0 		 0.79 		 0.91 |
# | 5.0 		 0.83 		 0.26 |
# | 5.0 		 0.58 		 0.5 |
# | 5.0 		 0.33 		 0.41 |
# | 5.0 		 0.1 		 0.24 |
# | 5.0 		 0.84 		 0.57 |
# -------------------------------------
# The s.d. of M is: 0.0
# The s.d. of D is: 0.3
# The s.d. of R is: 0.29
# -------------------------------------
# The mean of M is: 5.0
# The mean of D is: 0.51
# The mean of R is: 0.5
# -------------------------------------
# ____________________________________________________________________________________________________
# Agent 0 playing Agent 1: Reward: 1.4, Temptation: 2.4, Sucker: 0, Punishment: 1.1
# Agent 1 playing Agent 0: Reward: 4.0, Temptation: 6.7, Sucker: 0, Punishment: 2.8
# ____________________________________________________________________________________________________
# Agent 0 playing Agent 2: Reward: 1.4, Temptation: 2.4, Sucker: 0, Punishment: 1.1
# Agent 2 playing Agent 0: Reward: 2.4, Temptation: 2.5, Sucker: 0, Punishment: 0.0
# ____________________________________________________________________________________________________
# Agent 0 playing Agent 3: Reward: 1.4, Temptation: 2.4, Sucker: 0, Punishment: 1.1
# Agent 3 playing Agent 0: Reward: 6.4, Temptation: 9.2, Sucker: 0, Punishment: 2.8
# ____________________________________________________________________________________________________
# Agent 0 playing Agent 4: Reward: 1.4, Temptation: 2.4, Sucker: 0, Punishment: 1.1
# Agent 4 playing Agent 0: Reward: 6.7, Temptation: 10.9, Sucker: 0, Punishment: 4.2
# ____________________________________________________________________________________________________
# Agent 1 playing Agent 2: Reward: 4.0, Temptation: 6.7, Sucker: 0, Punishment: 2.8
# Agent 2 playing Agent 1: Reward: 2.4, Temptation: 2.5, Sucker: 0, Punishment: 0.0
# ____________________________________________________________________________________________________
# Agent 1 playing Agent 3: Reward: 4.0, Temptation: 6.7, Sucker: 0, Punishment: 2.8
# Agent 3 playing Agent 1: Reward: 6.4, Temptation: 9.2, Sucker: 0, Punishment: 2.8
# ____________________________________________________________________________________________________
# Agent 1 playing Agent 4: Reward: 4.0, Temptation: 6.7, Sucker: 0, Punishment: 2.8
# Agent 4 playing Agent 1: Reward: 6.7, Temptation: 10.9, Sucker: 0, Punishment: 4.2
# ____________________________________________________________________________________________________
# Agent 2 playing Agent 3: Reward: 2.4, Temptation: 2.5, Sucker: 0, Punishment: 0.0
# Agent 3 playing Agent 2: Reward: 6.4, Temptation: 9.2, Sucker: 0, Punishment: 2.8
# ____________________________________________________________________________________________________
# Agent 2 playing Agent 4: Reward: 2.4, Temptation: 2.5, Sucker: 0, Punishment: 0.0
# Agent 4 playing Agent 2: Reward: 6.7, Temptation: 10.9, Sucker: 0, Punishment: 4.2
# ____________________________________________________________________________________________________
# Agent 3 playing Agent 4: Reward: 6.4, Temptation: 9.2, Sucker: 0, Punishment: 2.8
# Agent 4 playing Agent 3: Reward: 6.7, Temptation: 10.9, Sucker: 0, Punishment: 4.2
#
# All players are playing a prisoners dilemma
# Tournament has started...
# Tournament has ended. The simulation took 39 minutes.
#     S.D.  Counts  seed   tournament_type
# 0    0.5     223   256  hetero_dr_sd_max
# 1    0.6     222   256  hetero_dr_sd_max
# 2    0.7     215   256  hetero_dr_sd_max
# 3    0.8     197   256  hetero_dr_sd_max
# 4    0.9     175   256  hetero_dr_sd_max
# 5    1.0     176   256  hetero_dr_sd_max
# 6    1.1     162   256  hetero_dr_sd_max
# 7    1.2     160   256  hetero_dr_sd_max
# 8    1.3     148   256  hetero_dr_sd_max
# 9    1.4     116   256  hetero_dr_sd_max
# 10   1.5     108   256  hetero_dr_sd_max
# 11   1.6      83   256  hetero_dr_sd_max
# 12   1.7      67   256  hetero_dr_sd_max
# 13   1.8      53   256  hetero_dr_sd_max
# 14   1.9      46   256  hetero_dr_sd_max
# 15   2.0      37   256  hetero_dr_sd_max
# 16   2.1      27   256  hetero_dr_sd_max
# 17   2.2      14   256  hetero_dr_sd_max
# 18   2.3      12   256  hetero_dr_sd_max
# 19   2.4       7   256  hetero_dr_sd_max
# 20   2.5       8   256  hetero_dr_sd_max
# 21   2.6       4   256  hetero_dr_sd_max
# 22   2.7       0   256  hetero_dr_sd_max
# 23   2.8       0   256  hetero_dr_sd_max
# 24   2.9       0   256  hetero_dr_sd_max
# 25   3.0       0   256  hetero_dr_sd_max
