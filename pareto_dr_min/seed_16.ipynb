# %%
import sys
sys.path.insert(1, '../')
from heterogenous_game_theory import *
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
# %matplotlib inline
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
plt.style.use('fivethirtyeight')
seed = 16
np.random.seed(seed)

tour_type = "pareto_dr_min"
M = [5, 1/10000]
R = ['power', 0.15, 1]
D = ['power', 0.2, 1]

agents = get_agents(homogenous = False, M = M, R = R, D = D)
check_parameters(agents)
compare_payoff_function(agents, default_payoff_functions)

tour = Tournament.create_play_tournament(
                 agents = agents, 
                 max_rounds = 10000, 
                 strategy_list = [defect, tit_for_tat, generous_tit_for_tat, cooperate], 
                 payoff_functions = default_payoff_functions, 
                 surveillance_penalty = True,
                 self_reward = selfreward, #default function
                 playing_each_other = True,
                 nr_strategy_changes = 10,
                 mutation_rate = 0.1,
                 init_fitnes_as_m = False,
                 noise = 0.05,
                 )
draw_stack(tour)
C_D_ratios_per_round_var(tour, constant = 1)
outliers = count_outliers(tour, constants = np.arange(0.5, 3.1, 0.1))
data = {'S.D.': list(outliers.keys()), 'Counts': list(outliers.values())}
df = pd.DataFrame.from_dict(data)
print(df)
df.to_csv("data/outliers/" + str(seed) + "_outlier_counts.csv", encoding='utf-8', index = False, float_format='%.1f')
save_tournament_csv(tour, seed = str(seed))
# Out:
# <style>.container { width:90% !important; }</style>
# AGENT PARAMETERS IN POPULATION
# -------------------------------------
#    M 		  D 		  R
# -------------------------------------
# | 5.0 		 0.34 		 0.16 |
# | 5.0 		 0.29 		 0.24 |
# | 5.0 		 0.74 		 0.22 |
# | 5.0 		 0.23 		 0.15 |
# | 5.0 		 0.24 		 0.36 |
# | 5.0 		 0.21 		 0.16 |
# | 5.0 		 0.31 		 0.17 |
# | 5.0 		 0.73 		 0.18 |
# | 5.0 		 0.44 		 0.33 |
# | 5.0 		 0.2 		 0.2 |
# | 5.0 		 0.64 		 0.22 |
# | 5.0 		 0.22 		 0.4 |
# | 5.0 		 0.26 		 0.55 |
# | 5.0 		 0.3 		 0.22 |
# | 5.0 		 0.36 		 0.16 |
# | 5.0 		 0.76 		 0.51 |
# | 5.0 		 0.24 		 0.72 |
# | 5.0 		 0.52 		 0.52 |
# | 5.0 		 0.41 		 0.25 |
# -------------------------------------
# The s.d. of M is: 0.0
# The s.d. of D is: 0.16
# The s.d. of R is: 0.19
# -------------------------------------
# The mean of M is: 5.0
# The mean of D is: 0.3
# The mean of R is: 0.41
# -------------------------------------
# ____________________________________________________________________________________________________
# Agent 0 playing Agent 1: Reward: 2.5, Temptation: 3.3, Sucker: 0, Punishment: 0.8
# Agent 1 playing Agent 0: Reward: 2.7, Temptation: 3.8, Sucker: 0, Punishment: 1.2
# ____________________________________________________________________________________________________
# Agent 0 playing Agent 2: Reward: 2.5, Temptation: 3.3, Sucker: 0, Punishment: 0.8
# Agent 2 playing Agent 0: Reward: 4.8, Temptation: 5.9, Sucker: 0, Punishment: 1.1
# ____________________________________________________________________________________________________
# Agent 0 playing Agent 3: Reward: 2.5, Temptation: 3.3, Sucker: 0, Punishment: 0.8
# Agent 3 playing Agent 0: Reward: 1.9, Temptation: 2.7, Sucker: 0, Punishment: 0.8
# ____________________________________________________________________________________________________
# Agent 0 playing Agent 4: Reward: 2.5, Temptation: 3.3, Sucker: 0, Punishment: 0.8
# Agent 4 playing Agent 0: Reward: 3.0, Temptation: 4.8, Sucker: 0, Punishment: 1.8
# ____________________________________________________________________________________________________
# Agent 1 playing Agent 2: Reward: 2.7, Temptation: 3.8, Sucker: 0, Punishment: 1.2
# Agent 2 playing Agent 1: Reward: 4.8, Temptation: 5.9, Sucker: 0, Punishment: 1.1
# ____________________________________________________________________________________________________
# Agent 1 playing Agent 3: Reward: 2.7, Temptation: 3.8, Sucker: 0, Punishment: 1.2
# Agent 3 playing Agent 1: Reward: 1.9, Temptation: 2.7, Sucker: 0, Punishment: 0.8
# ____________________________________________________________________________________________________
# Agent 1 playing Agent 4: Reward: 2.7, Temptation: 3.8, Sucker: 0, Punishment: 1.2
# Agent 4 playing Agent 1: Reward: 3.0, Temptation: 4.8, Sucker: 0, Punishment: 1.8
# ____________________________________________________________________________________________________
# Agent 2 playing Agent 3: Reward: 4.8, Temptation: 5.9, Sucker: 0, Punishment: 1.1
# Agent 3 playing Agent 2: Reward: 1.9, Temptation: 2.7, Sucker: 0, Punishment: 0.8
# ____________________________________________________________________________________________________
# Agent 2 playing Agent 4: Reward: 4.8, Temptation: 5.9, Sucker: 0, Punishment: 1.1
# Agent 4 playing Agent 2: Reward: 3.0, Temptation: 4.8, Sucker: 0, Punishment: 1.8
# ____________________________________________________________________________________________________
# Agent 3 playing Agent 4: Reward: 1.9, Temptation: 2.7, Sucker: 0, Punishment: 0.8
# Agent 4 playing Agent 3: Reward: 3.0, Temptation: 4.8, Sucker: 0, Punishment: 1.8
#
# All players are playing a prisoners dilemma
# Tournament has started...
# Tournament has ended. The simulation took 39 minutes.
# No handles with labels found to put in legend.
#     S.D.  Counts
# 0    0.5     278
# 1    0.6     258
# 2    0.7     253
# 3    0.8     224
# 4    0.9     221
# 5    1.0     217
# 6    1.1     188
# 7    1.2     169
# 8    1.3     167
# 9    1.4     136
# 10   1.5      99
# 11   1.6      70
# 12   1.7      54
# 13   1.8      48
# 14   1.9      33
# 15   2.0      32
# 16   2.1      24
# 17   2.2      13
# 18   2.3      17
# 19   2.4      15
# 20   2.5       2
# 21   2.6       1
# 22   2.7       0
# 23   2.8       0
# 24   2.9       0
# 25   3.0       0
