# %%
import sys
sys.path.insert(1, '../')
from heterogenous_game_theory import *
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
# %matplotlib inline
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
plt.style.use('fivethirtyeight')
seed = 2
np.random.seed(seed)

tour_type = "pareto_dr_max"
M = [5, 1/10000]
R = ['power', 0.29, 25]
D = ['power', 0.39, 25]

agents = get_agents(homogenous = False, M = M, R = R, D = D)
check_parameters(agents)
compare_payoff_function(agents, default_payoff_functions)

tour = Tournament.create_play_tournament(
                 agents = agents, 
                 max_rounds = 10000, 
                 strategy_list = [defect, tit_for_tat, generous_tit_for_tat, cooperate], 
                 payoff_functions = default_payoff_functions, 
                 surveillance_penalty = True,
                 self_reward = selfreward, #default function
                 playing_each_other = True,
                 nr_strategy_changes = 10,
                 mutation_rate = 0.1,
                 init_fitnes_as_m = False,
                 noise = 0.05,
                 )
draw_stack(tour)
C_D_ratios_per_round_var(tour, constant = 1)
outliers = count_outliers(tour, constants = np.arange(0.5, 3.1, 0.1))
data = {'S.D.': list(outliers.keys()), 'Counts': list(outliers.values())}
df = pd.DataFrame.from_dict(data)
print(df)
df.to_csv("data/outliers/" + str(seed) + "_outlier_counts.csv", encoding='utf-8', index = False, float_format='%.1f')
save_tournament_csv(tour, seed = str(seed))
# Out:
# <style>.container { width:90% !important; }</style>
# AGENT PARAMETERS IN POPULATION
# -------------------------------------
#    M 		  D 		  R
# -------------------------------------
# | 5.0 		 0.0 		 0.31 |
# | 5.0 		 0.0 		 0.32 |
# | 5.0 		 0.0 		 0.29 |
# | 5.0 		 0.0 		 0.29 |
# | 5.0 		 0.0 		 0.3 |
# | 5.0 		 0.0 		 0.31 |
# | 5.0 		 0.0 		 0.31 |
# | 5.0 		 0.0 		 0.29 |
# | 5.0 		 0.0 		 0.3 |
# | 5.0 		 0.0 		 0.29 |
# | 5.0 		 0.0 		 0.29 |
# | 5.0 		 0.0 		 0.31 |
# | 5.0 		 0.0 		 0.35 |
# | 5.0 		 0.0 		 0.3 |
# | 5.0 		 0.0 		 0.31 |
# | 5.0 		 0.0 		 0.29 |
# | 5.0 		 0.0 		 0.3 |
# | 5.0 		 0.0 		 0.29 |
# | 5.0 		 0.0 		 0.29 |
# -------------------------------------
# The s.d. of M is: 0.0
# The s.d. of D is: 0.01
# The s.d. of R is: 0.0
# -------------------------------------
# The mean of M is: 5.0
# The mean of D is: 0.3
# The mean of R is: 0.0
# -------------------------------------
# ____________________________________________________________________________________________________
# Agent 0 playing Agent 1: Reward: 1.6, Temptation: 3.1, Sucker: 0, Punishment: 1.6
# Agent 1 playing Agent 0: Reward: 1.6, Temptation: 3.2, Sucker: 0, Punishment: 1.6
# ____________________________________________________________________________________________________
# Agent 0 playing Agent 2: Reward: 1.6, Temptation: 3.1, Sucker: 0, Punishment: 1.6
# Agent 2 playing Agent 0: Reward: 1.4, Temptation: 2.9, Sucker: 0, Punishment: 1.4
# ____________________________________________________________________________________________________
# Agent 0 playing Agent 3: Reward: 1.6, Temptation: 3.1, Sucker: 0, Punishment: 1.6
# Agent 3 playing Agent 0: Reward: 1.4, Temptation: 2.9, Sucker: 0, Punishment: 1.4
# ____________________________________________________________________________________________________
# Agent 0 playing Agent 4: Reward: 1.6, Temptation: 3.1, Sucker: 0, Punishment: 1.6
# Agent 4 playing Agent 0: Reward: 1.5, Temptation: 3.0, Sucker: 0, Punishment: 1.5
# ____________________________________________________________________________________________________
# Agent 1 playing Agent 2: Reward: 1.6, Temptation: 3.2, Sucker: 0, Punishment: 1.6
# Agent 2 playing Agent 1: Reward: 1.4, Temptation: 2.9, Sucker: 0, Punishment: 1.4
# ____________________________________________________________________________________________________
# Agent 1 playing Agent 3: Reward: 1.6, Temptation: 3.2, Sucker: 0, Punishment: 1.6
# Agent 3 playing Agent 1: Reward: 1.4, Temptation: 2.9, Sucker: 0, Punishment: 1.4
# ____________________________________________________________________________________________________
# Agent 1 playing Agent 4: Reward: 1.6, Temptation: 3.2, Sucker: 0, Punishment: 1.6
# Agent 4 playing Agent 1: Reward: 1.5, Temptation: 3.0, Sucker: 0, Punishment: 1.5
# ____________________________________________________________________________________________________
# Agent 2 playing Agent 3: Reward: 1.4, Temptation: 2.9, Sucker: 0, Punishment: 1.4
# Agent 3 playing Agent 2: Reward: 1.4, Temptation: 2.9, Sucker: 0, Punishment: 1.4
# ____________________________________________________________________________________________________
# Agent 2 playing Agent 4: Reward: 1.4, Temptation: 2.9, Sucker: 0, Punishment: 1.4
# Agent 4 playing Agent 2: Reward: 1.5, Temptation: 3.0, Sucker: 0, Punishment: 1.5
# ____________________________________________________________________________________________________
# Agent 3 playing Agent 4: Reward: 1.4, Temptation: 2.9, Sucker: 0, Punishment: 1.4
# Agent 4 playing Agent 3: Reward: 1.5, Temptation: 3.0, Sucker: 0, Punishment: 1.5
#
# All players are playing a prisoners dilemma
# Tournament has started...
# /
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-b767248fc1f3> in <module>()
#      32                  mutation_rate = 0.1,
#      33                  init_fitnes_as_m = False,
# ---> 34                  noise = 0.05,
#      35                  )
#      36 draw_stack(tour)
#
# C:\Users\vocelik\Documents\projects\heterogenous_game_theory\heterogenous_game_theory\tournament.py in create_play_tournament(cls, agents, max_rounds, strategy_list, payoff_functions, surveillance_penalty, self_reward, playing_each_other, nr_strategy_changes, mutation_rate, init_fitnes_as_m, noise)
#     444         tournament.init_fitness(init_fitnes_as_m=init_fitnes_as_m)
#     445
# --> 446         tournament.play(self_reward, playing_each_other, nr_strategy_changes, mutation_rate)
#     447
#     448         return tournament
#
# C:\Users\vocelik\Documents\projects\heterogenous_game_theory\heterogenous_game_theory\tournament.py in play(self, self_reward, playing_each_other, nr_strategy_changes, mutation_rate)
#     356                 for agent_1, agent_2, data in self.graph.edges(data=True): # data: include edge-attributes in the iteration
#     357                     # todo: we are looping though edges twice.. this could be done only once.
# --> 358                     self.play_prisoners_dilema(agent_1, agent_2, data)
#     359
#     360             for _ in range(nr_strategy_changes):
#
# C:\Users\vocelik\Documents\projects\heterogenous_game_theory\heterogenous_game_theory\tournament.py in play_prisoners_dilema(self, agent_1, agent_2, game)
#     281
#     282         # let agents' strategies choose an action
# --> 283         action_1 = agent_1.select_action(game['history_1'], game['history_2'], self.noise)
#     284         action_2 = agent_2.select_action(game['history_2'], game['history_1'], self.noise)
#     285
#
# C:\Users\vocelik\Documents\projects\heterogenous_game_theory\heterogenous_game_theory\agent.py in select_action(self, selfmoves, othermoves, noise_threshold)
#      50             return random_action()
#      51         else:
# ---> 52             return self._strategy(selfmoves, othermoves)
#      53
#      54     def get_current_strategy(self):
#
# C:\Users\vocelik\Documents\projects\heterogenous_game_theory\heterogenous_game_theory\strategies.py in generous_tit_for_tat(selfmoves, othermoves)
#      31         return C
#      32     else:
# ---> 33         return np.random.choice([C, D], p=[0.3, 0.7])
#      34 generous_tit_for_tat.name = 'generous_tit_for_tat'
#      35
#
# KeyboardInterrupt:
